# %%
import openai
import os

# from dotenv import load_dotenv, find_dotenv
# _ = load_dotenv(find_dotenv())

# openai.api_key  = os.getenv('OPENAI_API_KEY')

# openai.api_key = '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'
openai.api_key = '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'

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response, response.choices[0].message["content"]

# %%
client = openai.OpenAI()

def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0
    )
    return response.choices[0].message.content

# %%
product_data_format = '''
{
    "product_id": "<placeholder>",
    "url": "<placeholder>",
    "tên sản phẩm": "<placeholder>",
    "màu sắc": "<placeholder>",
    "giá": {
        "giá hiện tại": "<placeholder>",
        "giá gốc": "<placeholder>",
        "phần trăm giảm giá": "<placeholder>",
        "khuyến mãi áp dụng đến": "<placeholder>"
    },
    "thông số kỹ thuật": {
        "Màn hình": {
            "Công nghệ màn hình": "<placeholder>",
            "Độ phân giải": "<placeholder>",
            "Màn hình rộng": "<placeholder>",
            "Độ sáng tối đa": "<placeholder>",
            "Mặt kính cảm ứng": "<placeholder>"
        },
        "Camera sau": {
            "Độ phân giải": "<placeholder>",
            "Quay phim": "<placeholder>",
            "Đèn Flash": "<placeholder>",
            "Tính năng": "<placeholder>"
        },
        "Camera trước": {
            "Độ phân giải": "<placeholder>",
            "Tính năng": "<placeholder>"
        },
        "Hệ điều hành & CPU": {
            "Hệ điều hành": "<placeholder>",
            "Chip xử lý (CPU)": "<placeholder>",
            "Tốc độ CPU": "<placeholder>",
            "Chip đồ họa (GPU)": "<placeholder>"
        },
        "Bộ nhớ & Lưu trữ": {
            "RAM": "<placeholder>",
            "Dung lượng lưu trữ": "<placeholder>",
            "Danh bạ": "<placeholder>",
            "Dung lượng còn lại (khả dụng) khoảng": "<placeholder>"
        },
        "Kết nối": {
            "Mạng di động": "<placeholder>",
            "SIM": "<placeholder>",
            "Wifi": "<placeholder>",
            "GPS": "<placeholder>",
            "Bluetooth": "<placeholder>",
            "Cổng kết nối/sạc": "<placeholder>",
            "Jack tai nghe": "<placeholder>"
        },
        "Pin & Sạc": {
            "Dung lượng pin": "<placeholder>",
            "Loại pin": "<placeholder>",
            "Hỗ trợ sạc tối đa": "<placeholder>",
            "Công nghệ pin": "<placeholder>"
        },
        "Tiện ích": {
            "Bảo mật nâng cao": "<placeholder>",
            "Tính năng đặc biệt": "<placeholder>",
            "Kháng nước, bụi": "<placeholder>",
            "Ghi âm": "<placeholder>",
            "Xem phim": "<placeholder>",
            "Nghe nhạc": "<placeholder>"
        },
        "Thông tin chung": {
            "Thiết kế": "<placeholder>",
            "Chất liệu": "<placeholder>",
            "Kích thước, khối lượng": "<placeholder>",
            "Thời điểm ra mắt": "<placeholder>",
            "Hãng": "<placeholder>"
        }
    },
    "đánh giá": {
        "điểm đánh giá trung bình": "<placeholder>",
        "số lượng đánh giá": "<placeholder>"
    }
}
'''

# %%
output_format = '''
{
"product_id": "<placeholder>",
"url": "<placeholder>",
"questions": [
{
"qa_id": "<placeholder, example, p_’product_id’_qa_01>",
"question": "<placeholder>",
"question_category": "<placeholder>",
"short_answer": "<placeholder>",
"long_answer": "<placeholder>"
},
{
"qa_id": "<placeholder, example, p_’product_id’_qa_20>",
"question": "<placeholder>",
"question_category": "<placeholder>",
"short_answer": "<placeholder>",
"answer": "<placeholder>"
}
]
}
'''

# %%
product_data = '''
{"product_id": "dtdd_samsung-galaxy-a25-8gb", "url": "https://thegioididong.com/dtdd/samsung-galaxy-a25-8gb", "tên sản phẩm": "Điện thoại Samsung Galaxy A25 5G 8GB", "màu sắc": "Đen", "giá": {"giá hiện tại": "6.490.000₫", "giá gốc": "6.990.000₫", "phần trăm giảm giá": "7%", "khuyến mãi áp dụng đến": "Giá và khuyến mãi dự kiến áp dụng đến 23:00 | 08/04"}, "thông số kỹ thuật": {"Màn hình": {"Công nghệ màn hình": "Super AMOLED", "Độ phân giải": "Full HD+ (1080 x 2340 Pixels)", "Màn hình rộng": "6.5\" - Tần số quét 120 Hz", "Độ sáng tối đa": "1000 nits", "Mặt kính cảm ứng": "Kính cường lực Corning Gorilla Glass 5"}, "Camera sau": {"Độ phân giải": "Chính 50 MP & Phụ 8 MP, 2 MP", "Quay phim": ["HD 720p@480fps", "HD 720p@240fps", "FullHD 1080p@60fps", "FullHD 1080p@30fps", "FullHD 1080p@120fps", "4K 2160p@30fps"], "Đèn Flash": "Có", "Tính năng": ["Zoom kỹ thuật số", "Xóa phông", "Video chuyên nghiệp", "Tự động lấy nét (AF)", "Trôi nhanh thời gian (Time Lapse)", "Toàn cảnh (Panorama)", "Siêu độ phân giải", "Siêu cận (Macro)", "Quét tài liệu", "Quét mã QR", "Quay Siêu chậm (Super Slow Motion)", "Quay chậm (Slow Motion)", "Nhãn dán (AR Stickers)", "Làm đẹp", "HDR", "Góc siêu rộng (Ultrawide)", "Chụp ảnh chuyển động", "Chụp một chạm", "Chụp hẹn giờ", "Chống rung quang học (OIS)", "Chống rung kỹ thuật số (VDIS)", "Chuyên nghiệp (Pro)", "Bộ lọc màu", "Ban đêm (Night Mode)"]}, "Camera trước": {"Độ phân giải": "13 MP", "Tính năng": ["Xóa phông", "Trôi nhanh thời gian (Time Lapse)", "Quay video HD", "Quay video Full HD", "Nhãn dán (AR Stickers)", "Làm đẹp", "HDR", "Góc rộng (Wide)", "Flash màn hình", "Chụp ảnh chuyển động", "Chụp đêm", "Chụp một chạm", "Chụp hẹn giờ", "Bộ lọc màu"]}, "Hệ điều hành & CPU": {"Hệ điều hành": "Android 14", "Chip xử lý (CPU)": "Exynos 1280 8 nhân", "Tốc độ CPU": "2 nhân 2.4 GHz & 6 nhân 2 GHz", "Chip đồ họa (GPU)": "Mali-G68"}, "Bộ nhớ & Lưu trữ": {"RAM": "8 GB", "Dung lượng lưu trữ": "128 GB", "Dung lượng còn lại (khả dụng) khoảng": "108 GB", "Thẻ nhớ": "MicroSD, hỗ trợ tối đa 1 TB", "Danh bạ": "Không giới hạn"}, "Kết nối": {"Mạng di động": "Hỗ trợ 5G", "SIM": "2 Nano SIM", "Wifi": ["Wi-Fi hotspot", "Wi-Fi Direct", "Wi-Fi 802.11 a/b/g/n/ac", "Dual-band (2.4 GHz/5 GHz)"], "GPS": ["QZSS", "GPS", "GLONASS", "GALILEO", "BEIDOU"], "Bluetooth": "v5.3", "Cổng kết nối/sạc": "Type-C", "Jack tai nghe": "3.5 mm", "Kết nối khác": "NFC"}, "Pin & Sạc": {"Dung lượng pin": "5000 mAh", "Loại pin": "Li-Po", "Hỗ trợ sạc tối đa": "25 W", "Công nghệ pin": "Tiết kiệm pin\nSạc pin nhanh"}, "Tiện ích": {"Bảo mật nâng cao": "Mở khoá vân tay cạnh viền\nMở khoá khuôn mặt", "Tính năng đặc biệt": ["Ứng dụng kép (Dual Messenger)", "Đa cửa sổ (chia đôi màn hình)", "Âm thanh Dolby Atmos", "Vision Booster", "Trợ lý ảo Google Assistant", "Thu nhỏ màn hình sử dụng một tay", "Mở rộng bộ nhớ RAM", "Không gian thứ hai (Thư mục bảo mật)", "Chế độ đơn giản (Giao diện đơn giản)", "Chặn tin nhắn", "Chặn cuộc gọi", "Chạm 2 lần tắt/sáng màn hình"], "Ghi âm": "Ghi âm mặc định\nGhi âm cuộc gọi", "Radio": "Có", "Xem phim": "Có", "Nghe nhạc": "Có"}, "Thông tin chung": {"Thiết kế": "Nguyên khối", "Chất liệu": "Khung & Mặt lưng nhựa", "Kích thước, khối lượng": "Dài 161 mm - Ngang 76.5 mm - Dày 8.3 mm - Nặng 197 g", "Thời điểm ra mắt": "12/2023", "Hãng": "Samsung"}}, "đánh giá": {"điểm đánh giá trung bình": "3.2", "số lượng đánh giá": "14"}}

'''

# %%
questions_created_1 = '''
{
"product_id": "dtdd_samsung-galaxy-a25-8gb",
"url": "https://thegioididong.com/dtdd/samsung-galaxy-a25-8gb",
"questions": [
{
"qa_id": "p_dtdd_samsung-galaxy-a25-8gb_qa_01",
"question": "Điện thoại Samsung Galaxy A25 5G 8GB có giá bao nhiêu?",
"question_category": "thông tin chung",
"short_answer": "6.490.000₫",
"long_answer": "Điện thoại Samsung Galaxy A25 5G 8GB hiện đang có giá là 6.490.000₫."
},
{
"qa_id": "p_dtdd_samsung-galaxy-a25-8gb_qa_02",
"question": "Màn hình của Điện thoại Samsung Galaxy A25 5G 8GB có công nghệ gì?",
"question_category": "thông số kỹ thuật",
"short_answer": "Super AMOLED",
"long_answer": "Màn hình của Điện thoại Samsung Galaxy A25 5G 8GB sử dụng công nghệ Super AMOLED."
},
{
"qa_id": "p_dtdd_samsung-galaxy-a25-8gb_qa_03",
"question": "Camera sau của Điện thoại Samsung Galaxy A25 5G 8GB có độ phân giải bao nhiêu?",
"question_category": "thông số kỹ thuật",
"short_answer": "Chính 50 MP & Phụ 8 MP, 2 MP",
"long_answer": "Camera sau của Điện thoại Samsung Galaxy A25 5G 8GB có độ phân giải chính là 50 MP và phụ là 8 MP và 2 MP."
},
{
"qa_id": "p_dtdd_samsung-galaxy-a25-8gb_qa_04",
"question": "Hệ điều hành của Điện thoại Samsung Galaxy A25 5G 8GB là gì?",
"question_category": "thông số kỹ thuật",
"short_answer": "Android 14",
"long_answer": "Điện thoại Samsung Galaxy A25 5G 8GB sử dụng hệ điều hành Android 14."
},
{
"qa_id": "p_dtdd_samsung-galaxy-a25-8gb_qa_05",
"question": "Dung lượng pin của Điện thoại Samsung Galaxy A25 5G 8GB là bao nhiêu?",
"question_category": "thông số kỹ thuật",
"short_answer": "5000 mAh",
"long_answer": "Điện thoại Samsung Galaxy A25 5G 8GB có dung lượng pin lên đến 5000 mAh."
},
{
"qa_id": "p_dtdd_samsung-galaxy-a25-8gb_qa_06",
"question": "Điện thoại Samsung Galaxy A25 5G 8GB có tính năng đặc biệt nào?",
"question_category": "tiện ích",
"short_answer": "Ứng dụng kép (Dual Messenger), Đa cửa sổ (chia đôi màn hình), Âm thanh Dolby Atmos, Vision Booster, Trợ lý ảo Google Assistant, Thu nhỏ màn hình sử dụng một tay, Mở rộng bộ nhớ RAM, Không gian thứ hai (Thư mục bảo mật), Chế độ đơn giản (Giao diện đơn giản), Chặn tin nhắn, Chặn cuộc gọi, Chạm 2 lần tắt/sáng màn hình",
"long_answer": "Điện thoại Samsung Galaxy A25 5G 8GB có nhiều tính năng đặc biệt như ứng dụng kép (Dual Messenger), đa cửa sổ (chia đôi màn hình), âm thanh Dolby Atmos, vision booster, trợ lý ảo Google Assistant, thu nhỏ màn hình sử dụng một tay, mở rộng bộ nhớ RAM, không gian thứ hai (thư mục bảo mật), chế độ đơn giản (giao diện đơn giản), chặn tin nhắn, chặn cuộc gọi, chạm 2 lần tắt/sáng màn hình."
},
{
"qa_id": "p_dtdd_samsung-galaxy-a25-8gb_qa_07",
"question": "Điểm đánh giá trung bình của Điện thoại Samsung Galaxy A25 5G 8GB là bao nhiêu?",
"question_category": "đánh giá",
"short_answer": "3.2",
"long_answer": "Điểm đánh giá trung bình của Điện thoại Samsung Galaxy A25 5G 8GB là 3.2."
}
]
}
'''

# %%
prompt = f'''
Please act as a data syntheizer.

Your task is to create a high quality dataset for the task of question answering over table in the domain of e-commerce for Vietnamese (Vietnamese e-commerece TableQA). The task has as input only a question of customer and the output is the answer to that question. To solve the task requires two steps: first retrieve the tables related to the question and next, process that retrieved relevant table to produce the answer.

You will be provided a JSON content of PRODUCT_DATA including large fields such as: “product_id”, "url", "tên sản phẩm", “màu sắc”, “giá”, “thông số kỹ thuật”, “thông tin chung”, “tiện ích”,  "đánh giá". This json content can form a TABLE containing product data to serve the task. 
Format of PRODUCT_DATA is as below:
Format of PRODUCT_                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               DATA:
{product_data_format}

Please create Vietnamese QUESTION and ANSWER pairs for the Vietnamese e-commerce TableQA task based on the given TABLE and following instructions.

You have principles to do this.
1. Your response should be the maximum number of words that can be generated.
2. This principle is VERY IMPORTANT. Since the task's input is only a question of customer and no table, you need to state the product name in question or else the product in the question must be what is being searched from a database of product. For example, you should ask “"Điện thoại iPhone 15 Pro 128GB có bao nhiêu phiên bản màu sắc?” or “Điện thoại nào có dung lượng 128GB và RAM 8GB?” instead of questions like “Điện thoại này có bao nhiêu phiên bản màu sắc?”, “Tên sản phẩm này là gi?”,  “Sản phẩm này tên gì?”, “Sản phầm này có ID là gì?”, "Thiết bị nào...?" or similar questions.
3. Possible question categories include: “thông tin chung” (“giá”, “thiết kế”, “kích thước”, etc.), “thông số kỹ thuật”, tiện ích”, "đánh giá”. Each question catogry must have at least 1 question and answer pair. Do not ask questions about "màu sắc" và "dung lượng".
4. You need to generate 2 ANSWER for each question: a short-answer which is just the span extracted from the TABLE, and a long answer which is generated as a free-style long containing the span extracted from the TABLE
5. Ensure the questions created can be answered using information from the TABLE.
6. AT LEAST 50 questions are generated to cover every detail of the table and every question categories .
7. Questions created need to be creativity and diverse in how they are asked

Your output should be in the JSON format like below:
Format of output:
{output_format}

This is the PRODUCT_DATA you are provided:
{product_data}

If you are given a number of questions that have already been created QUESTIONS_CREATED, please continue creating more questions in the order that follows the last QUESTIONS_CREATED question, avoid repeating these questions and follow all guidelines.
If QUESTIONS_CREATED is empty, you will start creating it from order 0.
{questions_created_1}

Again, you must follow all instructions. You will get rewards if you follow all the instructions, otherwise you will be punished.
'''

# %%
questions_created_2 = response_2 = get_completion(prompt)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 questions_created_2 = response_2 = get_completion(prompt)
#
# Cell In[21], line 5, in get_completion(prompt, model)
#       3 def get_completion(prompt, model="gpt-3.5-turbo"):
#       4     messages = [{"role": "user", "content": prompt}]
# ----> 5     response = client.chat.completions.create(
#       6         model=model,
#       7         messages=messages,
#       8         temperature=0
#       9     )
#      10     return response.choices[0].message.content
#
# File c:\Users\NamFam\anaconda3\envs\env-01\Lib\site-packages\openai\_utils\_utils.py:272, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     270             msg = f"Missing required argument: {quote(missing[0])}"
#     271     raise TypeError(msg)
# --> 272 return func(*args, **kwargs)
#
# ...

# %%
print(questions_created_2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(questions_created_2)
#
# NameError: name 'questions_created_2' is not defined

# %%
import json

# Load the JSON strings into dictionaries
questions_created_1_js = json.loads(questions_created_1)
questions_created_2_js = json.loads(questions_created_2)

# Merge the dictionaries
questions_created_merged_21 = {
    "product_id": questions_created_1_js["product_id"],
    "url": questions_created_1_js["url"],
    "questions": questions_created_1_js["questions"] + questions_created_2_js["questions"]
}

# Convert the merged dictionary back to a JSON string
questions_created_merged_21_js = json.dumps(questions_created_merged_21, ensure_ascii=False, indent=4)

print(questions_created_merged_21_js)

# %%
output_file_path = "questions_created_merged_21.json"
with open(output_file_path, "w", encoding="utf-8") as output_file:
    json.dump(questions_created_merged_21, output_file, ensure_ascii=False, indent=4)

print(f"Merged JSON saved to {output_file_path}")
